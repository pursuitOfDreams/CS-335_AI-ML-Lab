# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import numpy as np

# %%
def preprocessURL(url):
    fid = url.split('=')[-1]
    return fid


def extractFileContent(fid):


    # read it
    f = drive.CreateFile({'id': fid})  # just open an existing file
    f.FetchMetadata(fetch_all=True) 
    text = f.GetContentString() # or f.GetContentFile('im.png') to save a local file
    return text


def mse(pred, tr):
    return np.mean((tr-pred)**2)

# %%
compareGroundTruth(extractFileContent(fid), groundTruth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a7e279fd4e2c> in <module>
# ----> 1 compareGroundTruth(extractFileContent(fid), groundTruth)
#
# NameError: name 'compareGroundTruth' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Lab 10 Evaluation (File responses)/Lab 10 Evaluation (Responses) - Form responses 1.csv')

# %%
df.columns
# Out:
# Index(['Timestamp', 'Email address', 'Roll No.', 'Email Id', 'Name',
#        'q1_00.txt', 'q1_01.txt', 'q1_02.txt', 'q2_00.txt', 'q2_01.txt'],
#       dtype='object')

# %%
ls = extractFileContent(preprocessURL(df['q2_00.txt'][0]))

# %%
extractFileContent(preprocessURL(df['q2_00.txt'][2]))
# Out:
# '2\n3\n3\n2\n7\n5\n7\n5\n2\n2\n2\n2\n2\n5\n4\n5\n7\n2\n7\n7\n5\n3\n3\n5\n4\n2\n2\n5\n7\n3\n2\n4\n2\n4\n7\n7\n2\n7\n7\n4\n5\n3\n7\n5\n2\n4\n4\n4\n2\n2\n7\n3\n7\n4\n4\n2\n3\n7\n2\n4\n3\n2\n2\n4\n7\n2\n4\n4\n5\n7\n2\n7\n7\n2\n7\n2\n2\n3\n2\n2\n4\n2\n2\n3\n7\n2\n2\n4\n2\n4\n7\n2\n4\n3\n7\n3\n7\n7\n2\n2\n2\n7\n7\n4\n7\n7\n5\n7\n2\n2\n2\n2\n2\n2\n7\n2\n7\n2\n4\n7\n3\n2\n3\n4\n2\n4\n2\n2\n7\n7\n7\n2\n7\n4\n2\n4\n3\n2\n3\n7\n7\n7\n4\n2\n4\n4\n4\n2\n2\n4\n7\n4\n7\n2\n3\n7\n2\n2\n2\n2\n7\n7\n5\n7\n2\n2\n7\n2\n4\n5\n2\n5\n5\n5\n2\n7\n2\n5\n7\n5\n2\n7\n2\n7\n5\n5\n2\n7\n4\n3\n4\n5\n2\n4\n2\n7\n2\n2\n2\n7\n5\n7\n5\n2\n4\n7\n2\n5\n3\n7\n5\n4\n7\n4\n2\n2\n4\n4\n2\n5\n3\n2\n3\n2\n4\n2\n4\n7\n2\n3\n2\n7\n4\n3\n7\n7\n4\n7\n7\n3\n4\n4\n5\n2\n5\n5\n2\n4\n5\n4\n2\n4\n7\n4\n4\n5\n7\n5\n5\n7\n2\n2\n7\n7\n4\n2\n7\n7\n7\n4\n7\n7\n2\n7\n2\n3\n7\n7\n7\n2\n7\n7\n4\n4\n4\n7\n2\n7\n2\n2\n2\n7\n3\n4\n4\n2\n4\n4\n2\n2\n2\n5\n7\n2\n2\n7\n7\n4\n2\n5\n3\n4\n2\n3\n2\n2\n7\n2\n7\n5\n2\n4\n3\n2\n3\n2\n2\n2\n4\n4\n4\n4\n2
# ...

# %%
df['Marks_Q1_02'] = marks

# %%
df
# Out:
#                Timestamp         Email address   Roll No.  \
# 0    18/10/2022 14:18:12  190050074@iitb.ac.in  190050074
# 1    19/10/2022 00:21:26  200010021@iitb.ac.in  200010021
# 2    19/10/2022 09:45:12  200020012@iitb.ac.in  200020012
# 3    19/10/2022 10:31:35  200020120@iitb.ac.in  200020120
# 4    19/10/2022 10:30:37  200020135@iitb.ac.in  200020135
# ..                   ...                   ...        ...
# 184  21/10/2022 19:15:57  200050024@iitb.ac.in  200050024
# 185  21/10/2022 19:28:28  200050094@iitb.ac.in  200050094
# 186  21/10/2022 21:02:48  200050107@iitb.ac.in  200050107
# 187  21/10/2022 22:10:24  200050019@iitb.ac.in  200050019
# 188  21/10/2022 23:23:43  200050141@iitb.ac.in  200050141
#
#                  Email Id                   Name  \
# 0    190050074@iitb.ac.in           Nitish Kumar
# 1    200010021@iitb.ac.in   Dhairya Jhunjhunwala
# 2    200020012@iitb.ac.in             Adish Shah
# 3    200020120@iitb.ac.in         Sanchit Jindal
# ...

# %%
for question_ids in ['00','01','02']:
    marks=[]
    for index, row in df.iterrows():

        ## first question under q1_00
        ls = extractFileContent(preprocessURL(row['q1_' + question_ids + '.txt']))
        try:
            pred = np.array([eval(entry) for entry in ls.strip().split("\n")])
            tr = np.loadtxt("/content/drive/MyDrive/Lab 10 Evaluation (File responses)/Ground_Truth/q1/output"+ question_ids + ".txt")
            print(mse(pred,tr))
            marks.append(mse(pred,tr))

        except Exception as err:
            print(err)    
            marks.append(err)

    df['Marks_q1_'+question_ids] =marks
# Out:
# 332.3263135379617
# 0.083867046528374
# 0.6144086111757968
# 0.7271138092404786
# 0.10988805279744973
# 0.08150028428259223
# 1.3797126676491644
# 0.1551693960026367
# 0.7941060581888225
# 0.7228862539317973
# 0.7891140495941651
# 0.22231000000000045
# 0.7940662897540208
# 1.7891712763953218
# 0.7271147454071681
# 0.08150028428259223
# 0.08150028428259223
# 0.6054909259212626
# 1.5301750187117253
# 0.07413225090627144
# 0.08150028428259223
# 0.8003244500461963
# 0.6681048065331499
# 0.5119292287038499
# 0.4480044319210502
# 0.5139966440576
# 0.47147876154318624
# 0.6036922523050514
# 0.5119292287038499
# 0.7941060546649192
# 0.2917701982496698
# 0.34268948259717524
# 0.6505623546831002
# 0.35144858250837957
# 0.8023417100667954
# 0.11752703992463864
# 3.2391060070132314
# 7.147704999999995
# 0.6507983907020991
# 0.38877364781402907
# 0.38877364781402907
# 0.2915654925102319
# 2.264110336445944
# 0.6518426147556997
# 0.7271150040365313
# 0.6529468175011499
# 10.500331280309524
# ...

# %%
df = df.drop(columns=['Marks_Q1_02'])

# %%
import sklearn

# %%
from sklearn.metrics import accuracy_score

# %%
for question_ids in ['00','01']:
    marks=[]
    for index, row in df.iterrows():

        ## first question under q1_00
        ls = extractFileContent(preprocessURL(row['q2_' + question_ids + '.txt']))
        try:
            pred = np.array([eval(entry) for entry in ls.strip().split("\n")])
            tr = np.loadtxt("/content/drive/MyDrive/Lab 10 Evaluation (File responses)/Ground_Truth/q2/output"+ question_ids + ".txt")
            print(acc)
            acc = accuracy_score(tr,pred)
            marks.append(acc)

        except Exception as err:
            print(err)    
            marks.append(err)

    df['Marks_q2_'+question_ids] =marks
# Out:
# unexpected EOF while parsing (<string>, line 0)
# 0.24606644613835754
# 0.32138645189126996
# 0.24763411477060263
# 0.3040701855314253
# 0.2718107291816482
# unexpected EOF while parsing (<string>, line 0)
# 0.24606644613835754
# 0.24661297281748884
# 0.344340572414785
# 0.2540198475478211
# 0.3040701855314253
# 0.2348482669351359
# unexpected EOF while parsing (<string>, line 0)
# 0.3040701855314253
# 0.3050194160793902
# 0.24606644613835754
# 0.24737523371206674
# 0.3344887099093916
# 0.24572127139364303
# 0.3333812742700992
# 0.23929239177333525
# 0.3286926506543938
# 0.2721702862073925
# 0.2736660434344887
# 0.26720839925212136
# 0.2731195167553574
# unexpected EOF while parsing (<string>, line 0)
# 0.3377678699841795
# 0.27323457500359555
# 0.344340572414785
# 0.2682151589242054
# Found input variables with inconsistent numbers of samples: [69530, 20]
# 0.2682151589242054
# 0.23835754350640012
# 0.32931108873867393
# 0.3352653530849993
# ...

# %%
/content/drive/MyDrive/Lab 10 Evaluation (File responses)/Ground_Truth.zip

# %%
# !unzip "/content/drive/MyDrive/Lab 10 Evaluation (File responses)/Ground_Truth.zip"
# Out:
# Archive:  /content/drive/MyDrive/Lab 10 Evaluation (File responses)/Ground_Truth.zip
#    creating: Ground_Truth/q1/
#   inflating: Ground_Truth/q1/input00.txt
#   inflating: Ground_Truth/q1/input01.txt
#   inflating: Ground_Truth/q1/input02.txt
#   inflating: Ground_Truth/q1/output00.txt
#   inflating: Ground_Truth/q1/output01.txt
#   inflating: Ground_Truth/q1/output02.txt
#    creating: Ground_Truth/q2/
#   inflating: Ground_Truth/q2/input00.txt
#   inflating: Ground_Truth/q2/input01.txt
#   inflating: Ground_Truth/q2/output00.txt
#   inflating: Ground_Truth/q2/output01.txt

# %%
tr = np.loadtxt("/content/drive/MyDrive/Lab 10 Evaluation (File responses)/Ground_Truth/q1/output00.txt")

# %%
mse(pred,tr)
# Out:
# 332.3263135379617
